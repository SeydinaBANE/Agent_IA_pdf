# %%
from transformers import pipeline

# Création de l'agent
qa = pipeline("question-answering")

# Exemple
context = "La Tour Eiffel est une tour de fer située à Paris."
question = "Où se trouve la Tour Eiffel ?"

resultat = qa(question=question, context=context)
print(resultat['answer'])  # Réponse : Paris
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-cased-distilled-squad and revision 564e9b5 (https://huggingface.co/distilbert/distilbert-base-cased-distilled-squad).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[8], line 4
#       1 from transformers import pipeline
#       3 # Création de l'agent
# ----> 4 qa = pipeline("question-answering")
#       6 # Exemple
#       7 context = "La Tour Eiffel est une tour de fer située à Paris."
#
# ...
